# %%
from platform import python_version

print(python_version())
# Out:
# 3.11.5

# %% [markdown]
# # Import necessary libraries:

# %%
import json
import itertools
import numpy as np
import pandas as pd

# %%
# Data Reading Directory
directory = r'C:\\Gopi\\Study material\\GL\\Revision for final exam\\Capstone project\\Credit card default\\Review 2\\transactions.txt'

# Reading text from text file
with open(directory) as txt_file:
    lines = txt_file.readlines()

# Text in text file was in JSON format
# Converting text lines to JSON format and then restructuring as a dataframe 
trxn_data = []
for line in lines:
    trxn_data.append(json.loads(line))

# Replacing blank fields with NaN values
df = pd.DataFrame(trxn_data)
df = df.replace(r'', np.NaN)
df.head()
# Out:
#   accountNumber customerId  creditLimit  availableMoney  transactionDateTime  \
# 0     737265056  737265056       5000.0          5000.0  2016-08-13T14:27:32
# 1     737265056  737265056       5000.0          5000.0  2016-10-11T05:05:54
# 2     737265056  737265056       5000.0          5000.0  2016-11-08T09:18:39
# 3     737265056  737265056       5000.0          5000.0  2016-12-10T02:14:50
# 4     830329091  830329091       5000.0          5000.0  2016-03-24T21:04:46
#
#    transactionAmount         merchantName acqCountry merchantCountryCode  \
# 0              98.55                 Uber         US                  US
# 1              74.51          AMC #191138         US                  US
# 2               7.47           Play Store         US                  US
# 3               7.47           Play Store         US                  US
# 4              71.18  Tim Hortons #947751         US                  US
#
#   posEntryMode  ... echoBuffer currentBalance merchantCity merchantState  \
# 0           02  ...        NaN            0.0          NaN           NaN
# 1           09  ...        NaN            0.0          NaN           NaN
# 2           09  ...        NaN            0.0          NaN           NaN
# 3           09  ...        NaN            0.0          NaN           NaN
# 4           02  ...        NaN            0.0          NaN           NaN
#
#   merchantZip cardPresent posOnPremises recurringAuthInd  \
# 0         NaN       False           NaN              NaN
# 1         NaN        True           NaN              NaN
# 2         NaN       False           NaN              NaN
# 3         NaN       False           NaN              NaN
# 4         NaN        True           NaN              NaN
#
#   expirationDateKeyInMatch  isFraud
# 0                    False    False
# 1                    False    False
# 2                    False    False
# 3                    False    False
# 4                    False    False
#
# [5 rows x 29 columns]

# %%
df.shape # The data has 786363 rows , we prefer a smaller size for the capstone project & opt for sampling methods to reduce 
         # The overall size to a more appropriate size considering hardware requirements
# Out:
# (786363, 29)

# %%
df['isFraud'].value_counts() # Given the high imbalance in the target variable data, there is a high chance
                                                 # 'Random sampling' may lead to even more imbalanced dataset
# Out:
# isFraud
# False    773946
# True      12417
# Name: count, dtype: int64

# %%
df['isFraud'].value_counts(normalize=True) * 100  # Given the high imbalance in the target variable data, there is a high chance
                                                 # 'Random sampling' may lead to even more imbalanced dataset
# Out:
# isFraud
# False    98.420958
# True      1.579042
# Name: proportion, dtype: float64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [accountNumber, customerId, creditLimit, availableMoney, transactionDateTime, transactionAmount, merchantName, acqCountry, merchantCountryCode, posEntryMode, posConditionCode, merchantCategoryCode, currentExpDate, accountOpenDate, dateOfLastAddressChange, cardCVV, enteredCVV, cardLast4Digits, transactionType, echoBuffer, currentBalance, merchantCity, merchantState, merchantZip, cardPresent, posOnPremises, recurringAuthInd, expirationDateKeyInMatch, isFraud]
# Index: []
#
# [0 rows x 29 columns]

# %%
fraud_true = df[df['isFraud'] == True]
fraud_false = df[df['isFraud'] == False]

# Calculate the number of samples required for each class
n_samples_true = int(150000 * 0.01579042)  # Number of True samples
n_samples_false = 150000 - n_samples_true  # Number of False samples

# Sample from each stratum
sample_true = fraud_true.sample(n=n_samples_true, replace=False)
sample_false = fraud_false.sample(n=n_samples_false, replace=False)

# Concatenate the samples
stratified_sample = pd.concat([sample_true, sample_false])

# Shuffle the sample
stratified_sample = stratified_sample.sample(frac=1).reset_index(drop=True)

# %%
stratified_sample
# Out:
#        accountNumber customerId  creditLimit  availableMoney  \
# 0          302785707  302785707      15000.0         3165.82
# 1          459769579  459769579      15000.0        13362.73
# 2          668771382  668771382       5000.0         4786.28
# 3          690307166  690307166      15000.0         8230.64
# 4          447442368  447442368       1000.0          644.36
# ...              ...        ...          ...             ...
# 149995     536582330  536582330       2500.0         2288.18
# 149996     810471359  810471359       5000.0         3221.61
# 149997     865635967  865635967        500.0          200.20
# 149998     894938833  894938833      15000.0         4641.56
# 149999     700725639  700725639      50000.0         5197.59
#
#         transactionDateTime  transactionAmount  \
# 0       2016-11-02T15:36:59              16.28
# 1       2016-09-24T04:56:14               5.32
# 2       2016-12-19T11:11:56              95.44
# 3       2016-11-29T04:22:19             154.17
# 4       2016-06-10T00:36:53              25.36
# ...                     ...                ...
# 149995  2016-05-17T00:41:55             196.84
# 149996  2016-10-20T17:10:45               5.19
# 149997  2016-08-16T12:25:42             365.13
# 149998  2016-01-22T17:25:44             198.40
# 149999  2016-07-06T07:33:01               3.28
#
#                           merchantName acqCountry merchantCountryCode  \
# 0       Dinosaur Sandwitch Bar #303701         US                  US
# 1                           Play Store         US                  US
# 2                           amazon.com         US                  US
# 3                       Delta Airlines         US                  US
# 4                   Sunoco Gas #931794         US                  US
# ...                                ...        ...                 ...
# 149995             Rodeway Inn #105130         US                  US
# 149996                     walmart.com         US                  US
# 149997                  1st Restaurant         US                  US
# 149998                     WSC #998991         US                  US
# 149999                     oldnavy.com         US                  US
#
#        posEntryMode  ... echoBuffer currentBalance merchantCity merchantState  \
# 0                05  ...        NaN       11834.18          NaN           NaN
# 1                05  ...        NaN        1637.27          NaN           NaN
# 2                09  ...        NaN         213.72          NaN           NaN
# 3                05  ...        NaN        6769.36          NaN           NaN
# 4                02  ...        NaN         355.64          NaN           NaN
# ...             ...  ...        ...            ...          ...           ...
# 149995           05  ...        NaN         211.82          NaN           NaN
# 149996           09  ...        NaN        1778.39          NaN           NaN
# 149997           05  ...        NaN         299.80          NaN           NaN
# 149998           05  ...        NaN       10358.44          NaN           NaN
# 149999           09  ...        NaN       44802.41          NaN           NaN
#
#        merchantZip cardPresent posOnPremises recurringAuthInd  \
# 0              NaN        True           NaN              NaN
# 1              NaN       False           NaN              NaN
# 2              NaN       False           NaN              NaN
# 3              NaN       False           NaN              NaN
# 4              NaN        True           NaN              NaN
# ...            ...         ...           ...              ...
# 149995         NaN       False           NaN              NaN
# 149996         NaN       False           NaN              NaN
# 149997         NaN        True           NaN              NaN
# 149998         NaN       False           NaN              NaN
# 149999         NaN       False           NaN              NaN
#
#        expirationDateKeyInMatch  isFraud
# 0                         False    False
# 1                         False    False
# 2                         False     True
# 3                         False    False
# 4                         False    False
# ...                         ...      ...
# 149995                    False    False
# 149996                    False    False
# 149997                    False    False
# 149998                    False    False
# 149999                    False    False
#
# [150000 rows x 29 columns]

# %%
stratified_sample['isFraud'].value_counts()
# Out:
# isFraud
# False    147632
# True       2368
# Name: count, dtype: int64

# %%
stratified_sample['isFraud'].value_counts(normalize=True) * 100
# Out:
# isFraud
# False    98.421333
# True      1.578667
# Name: proportion, dtype: float64

# %%
stratified_sample[stratified_sample.duplicated()] # no duplicate values in the sample
# Out:
# Empty DataFrame
# Columns: [accountNumber, customerId, creditLimit, availableMoney, transactionDateTime, transactionAmount, merchantName, acqCountry, merchantCountryCode, posEntryMode, posConditionCode, merchantCategoryCode, currentExpDate, accountOpenDate, dateOfLastAddressChange, cardCVV, enteredCVV, cardLast4Digits, transactionType, echoBuffer, currentBalance, merchantCity, merchantState, merchantZip, cardPresent, posOnPremises, recurringAuthInd, expirationDateKeyInMatch, isFraud]
# Index: []
#
# [0 rows x 29 columns]

# %%
stratified_sample.to_csv('stratified_transactions.csv',index=False)
